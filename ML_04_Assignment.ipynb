# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('Height-Weight Data.csv')

# %% [markdown]
# # Starting the LR

# %%
             # Split the Data
from sklearn.model_selection import train_test_split as tts

# %%
xtrain,xtest,ytrain,ytest=tts(x,y,train_size=.70,random_state=1)

# %%
from sklearn.linear_model import LinearRegression
lr=LinearRegression()              # Object creating for LR
lr.fit(xtrain,ytrain)              # Train the ML model
# Out:
# LinearRegression()

# %%
pred=lr.predict(xtest)

# %% [markdown]
# # Error Testing

# %%
pred=lr.predict(xtest)

# %%
from sklearn.metrics import mean_squared_error    #MSE
mse=mean_squared_error(ytest,pred)  
mse
# Out:
# 110.89221516932378

# %%
from sklearn.metrics import mean_absolute_error    # MAE
mean_absolute_error(ytest, pred)
# Out:
# 8.279688660993672

# %% [markdown]
# # Accuracy Test

# %%
lr.score(xtest,ytest)
# Out:
# 0.7313258168853622

# %%
lr.score(df[['Height']],df.Weight)  # For full data set
# Out:
# 0.7323100609319788

# %%
lr.score(xtrain,ytrain)   # For Training Data set
# Out:
# 0.7327243206606744

# %% [markdown]
# # Best Fit Line

# %%
plt.figure(figsize=(12,8))
plt.scatter(df['Height'],df['Weight'])
plt.plot(xtest,lr.predict(xtest),color='red')
plt.xlabel('Height in Inches ')
plt.ylabel('Weight in pounds')
plt.title('Measurements of Height vs Weight')
# Out:
# Text(0.5, 1.0, 'Measurements of Height vs Weight')
